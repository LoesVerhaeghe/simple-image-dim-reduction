# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
SVI=pd.read_csv('data/SVI.csv', index_col=[0])
SVI.index=pd.to_datetime(SVI.index)

# %%
SVI
# Out:
#                    SVI
# 2023-10-13  120.245836
# 2023-10-17   97.988505
# 2023-10-20   89.473684
# 2023-10-23   72.649573
# 2023-10-26   82.026395
# ...                ...
# 2025-02-13  274.077562
# 2025-02-17  239.410681
# 2025-02-18  219.969193
# 2025-02-19  200.527704
# 2025-02-26  192.184497
#
# [90 rows x 1 columns]

# %%
plt.figure(figsize=(10,3), dpi=150)
plt.plot(SVI, '.-', label='SSVI')
plt.ylabel('SSVI (mL/g)')
plt.legend()

# %%
from os import listdir
import pandas as pd
dates=pd.to_datetime(sorted(listdir('data/microscope_images')))
df = pd.DataFrame({'dates': dates})
df.to_csv('dates.csv', index=False)
